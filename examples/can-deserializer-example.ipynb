# %%
dbc_file_path = '../opendbc/dbc/hyundai_2015_ccan.dbc'

# Define the CAN message parameters
arbitration_id = 902
dlc = 8
data = b'n\x84e\x04m\xc4c\xc4'

import cantools

# Load the DBC file
db = cantools.database.load_file(dbc_file_path)

# Decode the CAN message
message = db.decode_message(arbitration_id, data)

# Print the decoded message
print(message)
# Out:
# {'WHL_SPD_FL': 35.4375, 'WHL_SPD_AliveCounter_LSB': 2, 'WHL_SPD_FR': 35.15625, 'WHL_SPD_AliveCounter_MSB': 0, 'WHL_SPD_RL': 35.40625, 'WHL_SPD_Checksum_LSB': 3, 'WHL_SPD_RR': 35.09375, 'WHL_SPD_Checksum_MSB': 3}

# %%
# !ls
# Out:
# can-deserializer-example.ipynb kbhit.py
# joystick.py
